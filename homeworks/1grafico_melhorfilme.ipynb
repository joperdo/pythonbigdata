# %%
import pandas as pd

# %%
import numpy as np

# %%
#Indicados a melhor filme do Oscar 2024
#fonte: https://www.poder360.com.br/internacional/indicados-ao-oscar-2024-arrecadaram-us-28-bilhoes/

# %%
dictFilmes = {'Barbie': 145,
              'Oppenheimer': 100,
              'Assassinos das Lua das Flores': 200,
              'Pobres Criaturas': 35,
              'Os Rejeitados': 70,
              'Anatomia de Uma Queda': 7,
              'Vidas Passadas': 12,
              'American Fiction': 10,
              'Zona de Interesse': 15,
              'Maestro': 80
                }

# %%
serie1 = pd.Series(dictFilmes)
serie1
# Out:
# Barbie                           145
# Oppenheimer                      100
# Assassinos das Lua das Flores    200
# Pobres Criaturas                  35
# Os Rejeitados                     70
# Anatomia de Uma Queda              7
# Vidas Passadas                    12
# American Fiction                  10
# Zona de Interesse                 15
# Maestro                           80
# dtype: int64

# %%
filmes = ['Barbie', 'Oppenheimer', 'Assassinos das Lua das Flores',
           'Pobres Criaturas', 'Os Rejeitados',
           'Anatomia de Uma Queda', 'Vidas Passadas',
           'American Fiction', 'Zona de Interesse',
           'Maestro']

# %%
milhoes = [145, 100, 200,
          35, 70, 7,
          12, 10, 15,
          80]

# %%
serie2 = pd.Series(milhoes, index=filmes)
serie2
# Out:
# Barbie                           145
# Oppenheimer                      100
# Assassinos das Lua das Flores    200
# Pobres Criaturas                  35
# Os Rejeitados                     70
# Anatomia de Uma Queda              7
# Vidas Passadas                    12
# American Fiction                  10
# Zona de Interesse                 15
# Maestro                           80
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
serie2.plot()
# Out:
# <Axes: >

# %%
#Com isso podemos notar que, mesmo Oppenheimer tendo levado o prêmio de melhor filme, temos filmes com maiores custos de produção, como Barbie e Assassinos da Lua das Flores
#Uma oservação voltada ao gráfico, é que os nomes ficaram um em cima do outro
